# %%
import os

# Directory for the generated markdown files
output_dir = "./_portfolio"
os.makedirs(output_dir, exist_ok=True)

# Define grants data (title + excerpt)
grants = [
    ("Creation of an Interactive Online Seaweed Production Map",
     "Developing an interactive platform to support policy-making for Indonesia’s seaweed industry. KONEKSI Environment and Climate Change Extension Support, 2025–2026."),
    ("AI-Empowered and Video-Based Uplift of Paralympic Classification Systems",
     "Enhancing fairness and transparency in Paralympic classification through AI-driven video analysis. Follow Me AI Pty Ltd, 2024–2027."),
    ("Analytics for the Australian Grains Industry (AAGI)",
     "Development of advanced analytics and AI solutions to enhance productivity, sustainability, and profitability in the Australian grains sector. Funded by Grains Research & Development Corporation (GRDC), 2024–2027."),
    ("Breaking the Communication Barrier for the Australian Deaf Community",
     "Vision-based Australian Sign Language translation and production system for accessible communication. Google Asia Pacific Pte Ltd, 2023–2028."),
    ("Developing Applications of Satellite Imagery for Modelling Environmental and Social Impacts of Climate Change on Seaweed Farming",
     "Utilising satellite data to assess climate impacts on seaweed farming in Indonesia. KONEKSI Grant administered by Griffith University, 2023–2025."),
    ("Advancing Machine Perception: Countering Malicious Fake Visual Data",
     "Aims to strengthen AI model robustness and resilience against malicious visual data manipulation. Funded by ARC DECRA (DE230100477), 2023–2025."),
    ("Computer Vision-Based Human Activity Recognition and Intent Prediction",
     "Designing intelligent systems for real-time recognition and forecasting of human intent using multimodal visual data. Funded by CSIRO Scholarships, 2022–2025."),
    ("Two-way Auslan: Automatic Machine Translation of Australian Sign Language",
     "Building a bidirectional translation framework for Australian Sign Language to enhance accessible communication. ARC Discovery Projects (DP220100800), 2022–2024."),
    ("Detect Liveness Based on Dynamic Blood Vessel Pulsations and Eye Movements",
     "Developing liveness detection methods using physiological signals to distinguish real users from spoofed content. DAIRNet – AI for Decision Making, 2022."),
    ("An Automatic Deepfake Technology Integration Pipeline for Benchmarking Deepfake Detection Methods",
     "Developed a standardized pipeline to evaluate and benchmark deepfake detection algorithms under realistic conditions. DAIRNet – AI for Decision Making, 2022."),
    ("Mobile-based Automatic Australian Sign Language (Auslan) Translation",
     "Created a mobile-based Auslan translation system for everyday communication assistance. UTS ECR Research Capabilities Development Initiative, 2021–2022."),
    ("Sign Language Translation in the Wild",
     "Developed robust models for real-world sign language translation. Google Research Scholar Program, 2021–2022."),
]

# Generate markdown files
for i, (title, excerpt) in enumerate(grants, 1):
    filename = f"{output_dir}/portfolio-{i}.md"
    with open(filename, "w") as f:
        f.write(f"---\n")
        f.write(f"title: \"{title}\"\n")
        f.write(f"excerpt: \"{excerpt}\"\n")
        f.write(f"collection: portfolio\n")
        f.write(f"---\n")

output_dir
# Out:
# './_portfolio'
